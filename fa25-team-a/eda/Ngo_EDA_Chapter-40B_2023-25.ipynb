# %% [markdown]
# # EDA on CHAPA Chapter 40B Application Data from Oct 2023 to May 2025
# Author: Gia Bao (Belinda) Ngo
#
# **Dataset:** TOUCHABLE CHAPA Chapter 40B Application Data 2021-2023 & 10|2023-05|2025 (https://docs.google.com/spreadsheets/d/1xcW0qveqOPD-1JvJX1jaSJjPyCVVMGbY/edit?gid=690813037#gid=690813037)
#
#
# **Sheet used:** `23-25_data_updated`

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load and choose dataset
# ### Load Excel file and explore 23-25 sheets

# %%
file_path = "../data/TOUCHABLE CHAPA Chapter 40B Application Data 2021-2023 & 10_2023-05_2025.xlsx"

# list all sheet names in the Excel file
for sheet in pd.ExcelFile(file_path).sheet_names:
    print(f"{sheet}")
# Out:
# 2023-2025
# Saniya 2023-2025
# Clean Saniya 2023-2025
# Copy Clean Saniya 23-25
# 23-25_data_updated
# NEW 2023-2025
# 2021-2023
# CLEAN Kayla 2021-2023
# Copy of CLEAN Kayla 2021-2023
# Geocoded Kayla 2021-2023
# Kayla Working 2021-2023
# Kayla 2021-2023 Working 2.0
# CLEAN w stats Kayla 2021-2023

# %%
# # look at shape of all 23-25 sheets
# sheet_list = ["2023-2025",
#               "Saniya 2023-2025",
#               "Clean Saniya 2023-2025",
#               "Copy Clean Saniya 23-25",
#               "23-25_data_updated",
#               "NEW 2023-2025"]

# for sheet in sheet_list:
#     print(f"Sheet: {sheet}")
#     df = pd.read_excel(file_path, sheet_name=sheet)
#     print(df.shape, "\n")

# # look at info of 23-25 sheets with more columns
# sheet_list = ["Saniya 2023-2025",
#               "Clean Saniya 2023-2025",
#               "Copy Clean Saniya 23-25",
#               "23-25_data_updated"]

# for sheet in sheet_list:
#     print(f"Sheet: {sheet}")
#     df = pd.read_excel(file_path, sheet_name=sheet)
#     print(df.info(), "\n")

# # compare column names between sheets
# sheet_list = ["Saniya 2023-2025",
#               "Clean Saniya 2023-2025",
#               "Copy Clean Saniya 23-25",
#               "23-25_data_updated"]

# for sheet in sheet_list:
#     print(f"Sheet: {sheet}")
#     df = pd.read_excel(file_path, sheet_name=sheet)
#     print(df.columns.to_list(), "\n")

# %% [markdown]
# | Sheet name | Shape | Notes |
# |----------|----------|----------|
# | 2023-2025 | (1360, 14) | most likely raw data |
# | Saniya 2023-2025 | (1360, 31) | later columns contain stats, still in cleaning process |
# | Clean Saniya 2023-2025 | (1360, 29) | duplicate columns, still in cleaning process |
# | Copy Clean Saniya 23-25 | (1360, 20) | has "NA" values, race data from above sheet standardized here |
# | 23-25_data_updated | (1359, 29) | NA values are blanks here |
# | NEW 2023-2025 | (1360, 14) | most likely raw data |

# %% [markdown]
# ### Load chosen dataset: `23-25_data_updated`

# %%
df = pd.read_excel(file_path, sheet_name="23-25_data_updated")
df.head()
# Out:
#    ID Number Submission Date Submission Time  \
# 0        101      2024-05-28        13:31:01
# 1        101      2024-07-21        17:33:34
# 2       1595      2024-02-05        13:37:00
# 3       2159      2024-07-22        23:33:59
# 4       2685      2024-08-28        10:50:33
#
#                      Application Property Application City/Town  \
# 0    14 Caspian Way, Unit 23 ~ Leominster            Leominster
# 1   1 Millbrook Lane Unit 213 ~ Wakefield             Wakefield
# 2   11 Indian Woods Way, Unit 11 ~ Canton                Canton
# 3              24 Haywood Circle ~ Mendon                Mendon
# 4  6 Woodman Way, unit 204A ~ Newburyport           Newburyport
#
#       Application St Address Application Unit                   Source New  \
# 0             14 Caspian Way          unit 23                   MyMassHome
# 1  1 Millbrook Lane Unit 213              NaN                   MyMassHome
# 2        11 Indian Woods Way          unit 11     City of Boston Metrolist
# 3          24 Haywood Circle              NaN  Zillow/Trulia/Other Website
# 4              6 Woodman Way        unit 204a            Real Estate Agent
#
#     Age Race Combination Normalized  ... FTHB Class? Unique ID  \
# 0  65.0                       White  ...          No       497
# 1  65.0                       White  ...          No       696
# 2  56.0   Black or African American  ...         Yes       175
# 3  30.0   Black or African American  ...         Yes       706
# 4  58.0                       White  ...          No       888
#
#               Street Address         City  State  ZIP Match Status  \
# 0             14 Caspian Way   Leominster     MA  NaN        Match
# 1  1 Millbrook Lane Unit 213    Wakefield     MA  NaN        Match
# 2        11 Indian Woods Way       Canton     MA  NaN        Match
# 3          24 Haywood Circle       Mendon     MA  NaN        Match
# 4              6 Woodman Way  Newburyport     MA  NaN        Match
#
#    Match Type                         Matched Address  \
# 0   Non_Exact    14 CASPIAN ST, LEOMINSTER, MA, 01453
# 1       Exact    1 MILLBROOK LN, WAKEFIELD, MA, 01880
# 2       Exact  11 INDIAN WOODS WAY, CANTON, MA, 02021
# 3       Exact       24 HAYWOOD CIR, MENDON, MA, 01756
# 4       Exact   6 WOODMAN WAY, NEWBURYPORT, MA, 01950
#
#                               MSA
# 0                   Worcester, MA
# 1  Boston-Cambridge-Newton, MA-NH
# 2  Boston-Cambridge-Newton, MA-NH
# 3                   Worcester, MA
# 4  Boston-Cambridge-Newton, MA-NH
#
# [5 rows x 29 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1360 entries, 0 to 1359
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID Number                    1360 non-null   int64
#  1   Submission Date              1360 non-null   object
#  2   Submission Time              1360 non-null   object
#  3   Application Property         1359 non-null   object
#  4   Application City/Town        1359 non-null   object
#  5   Application St Address       1334 non-null   object
#  6   Application Unit             594 non-null    object
#  7   Source New                   1336 non-null   object
#  8   Age                          1359 non-null   float64
#  9   Race Combination Normalized  1360 non-null   object
#  10  Census Races                 1360 non-null   object
#  11  Disability                   1358 non-null   object
#  12  Current Residence Town/City  1358 non-null   object
#  13  Current Residence State      1359 non-null   object
#  14  HH Size                      1360 non-null   int64
#  15  Dependents                   1360 non-null   int64
#  16  HH Type Standardized         1360 non-null   object
#  17  HH Income                    1355 non-null   object
#  18  HH Assets                    1359 non-null   object
#  19  FTHB Class?                  1357 non-null   object
# dtypes: float64(1), int64(3), object(16)
# memory usage: 212.6+ KB

# %%
df["FTHB Class?"].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)
