# %%
import pandas as pd

# %%
df = pd.read_csv("data_updated.csv")

# %% [markdown]
# ## Describing the dataset

# %%
df.columns

# %%
df.Bedrooms.value_counts()

# %%
df["Age Restricted"].value_counts()

# %%
df["Town"].value_counts()

# %%
df["Full/Lite Documentation"].value_counts()

# %%
df["Duplicate"].value_counts()

# %%
print("The number of rows with null Closing Dates")
df[df["Closing Date"].isna()].count()

# %%
df.columns

# %%
df.info()

# %%
df.MSA.value_counts()
